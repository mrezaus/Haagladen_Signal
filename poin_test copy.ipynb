# %% [markdown]
# # Playground for poincare plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %% [markdown]
# ## Playground

# %%
## Load section
df = pd.read_csv('Output/Org/Splitted_HRV_pts.csv')

# %%
df.head()
# Out:
#     Name                                             Points           Stage
# 0  SN001  [126, 204, 295, 175, 211, 230, 187, 189, 266, ...  Sleep stage N1
# 1  SN001  [185, 274, 193, 270, 114, 253, 115, 191, 185, ...  Sleep stage N1
# 2  SN001  [198, 223, 127, 178, 118, 173, 122, 165, 131, ...  Sleep stage N1
# 3  SN001  [135, 203, 118, 129, 206, 143, 117, 183, 215, ...  Sleep stage N2
# 4  SN001  [202, 293, 198, 205, 197, 127, 157, 111, 187, ...  Sleep stage N2

# %%
df.loc[df['Stage'] == 'Sleep stage W']
# Out:
#         Name                                             Points          Stage
# 18     SN001  [174, 140, 118, 115, 178, 134, 123, 224, 215, ...  Sleep stage W
# 19     SN001  [107, 122, 230, 188, 228, 140, 204, 214, 119, ...  Sleep stage W
# 35     SN001  [182, 268, 128, 149, 171, 218, 115, 135, 120, ...  Sleep stage W
# 36     SN001  [160, 168, 300, 300, 118, 60, 98, 51, 55, 75, ...  Sleep stage W
# 37     SN001  [116, 121, 268, 123, 170, 106, 184, 201, 208, ...  Sleep stage W
# ...      ...                                                ...            ...
# 14671  SN154  [207, 207, 208, 209, 203, 218, 54, 131, 202, 1...  Sleep stage W
# 14672  SN154  [237, 237, 233, 227, 215, 217, 223, 228, 233, ...  Sleep stage W
# 14673  SN154  [260, 264, 264, 258, 254, 258, 264, 268, 259, ...  Sleep stage W
# 14674  SN154  [254, 251, 260, 264, 266, 259, 261, 261, 256, ...  Sleep stage W
# 14675  SN154  [277, 276, 271, 273, 278, 284, 276, 275, 288, ...  Sleep stage W
#
# [2687 rows x 3 columns]

# %%
df["Points"][0]
# Out:
# '[126, 204, 295, 175, 211, 230, 187, 189, 266, 117, 223, 277, 177, 118, 134, 120, 299, 157, 159, 162, 244, 210, 199, 122, 229, 221, 117, 256, 187, 109, 220, 203, 130, 193, 114, 292, 175, 119, 214, 118, 154, 170, 156, 193, 232, 308, 116, 119, 199, 117, 181, 119, 195, 114, 178, 225, 248, 142, 258, 127, 184, 124, 128, 196, 130, 186, 139, 437, 145, 90, 336, 127, 97, 220, 225, 131, 116, 173, 191, 208, 236, 131, 188, 286, 157, 193, 194, 161, 203, 300, 120, 137, 175, 184, 231, 240, 124, 213, 126, 127, 258, 194, 186, 242, 190, 122, 283, 215, 191, 126, 118, 192, 140, 196, 193, 219, 193, 169, 218, 186, 243, 173, 195, 125, 182, 165, 122, 227, 120, 202, 128, 114, 121, 234, 121, 123, 211, 208, 128, 194, 125, 200, 241, 124, 180, 113, 281, 156, 236, 189, 191, 233, 213, 127, 125, 278, 146, 180, 217, 113, 221, 130, 190, 205, 192, 112, 299, 137, 120, 124, 204, 115, 123, 177, 129, 191, 126, 195, 125, 193, 357, 118, 117, 188, 122, 185, 245, 111, 110, 241, 169, 309, 118, 108, 114, 116, 118, 211, 128, 302, 159, 211, 182, 214, 271, 156, 157, 219, 191, 211, 184, 225, 199, 208, 130, 179, 135, 189, 124, 216, 151, 155, 248, 318, 201, 128, 179, 112, 235, 126, 187, 166, 112, 217, 231, 194, 121, 115, 221, 185, 155, 201, 227, 289, 187, 195, 255, 116, 367, 143, 182, 121, 230]'

# %%
import ast

#Reading File and Trun into Array
text = df['Points'][4626]
# res = []
# for item in text:
#     res.append(ast.literal_eval(item))
text = ast.literal_eval(text)
print(text)
# Out:
# [279, 284, 270, 296, 287, 284, 272, 294, 286, 291, 275, 301, 294, 291, 282, 301, 296, 302, 286, 299, 293, 298, 296, 290, 294, 308, 299, 287, 300, 305, 293, 285, 300, 299, 284, 278, 286, 290, 274, 277, 279, 281, 264, 292, 269, 266, 275, 287, 264, 281, 280, 274, 272, 283, 110, 142, 87, 53, 66, 65, 52, 76, 54, 84, 260, 97, 98, 56, 85, 119, 58, 97, 158, 260, 276, 217, 60, 276, 267, 270, 281, 274, 278, 269, 264, 275, 274, 296, 307, 296, 287, 281, 293, 272, 292, 282, 297, 274, 288, 282, 292, 267, 269, 278, 282, 270, 286, 290, 290, 275, 295, 283, 281, 280, 297, 288, 285, 290, 297, 277, 297, 290, 302, 275, 308, 294, 293, 272, 304, 293, 287, 276, 297, 288, 289, 277, 293, 294, 282, 274, 289, 292, 281, 283, 296, 274, 291, 292, 283, 284, 302, 292, 287, 302, 310, 290, 284, 298, 296, 293, 282, 291, 306, 293, 290, 296, 304, 288, 289, 296, 299, 288, 291]

# %%
n1 = [text[i]/256 for i in range(0,len(text)-1)]
n2 = [text[i]/256 for i in range(1,len(text))]

plt.scatter(n2,n1)
plt.title(df['Name'][0])
plt.xlabel(df['Stage'][0])
plt.show()

# %%
def sigmoid(par):
    return 1/(1+np.exp(-1 * par))

# %%
def loss(arr):
    tmp=0
    for i in range(len(arr)-1):
        tmp += (arr[i+1] - arr[i])**2
    m = len(arr)
    loss = 1/(2*m) * (tmp)
    return loss

# %%
print(loss(text))
# Out:
# 3847.97233201581

# %%
df1 = pd.read_csv('Output/Org/Splitted_Log.csv')

# %%
df1.head()
# Out:
#                Name  Min  Max        Mean        Std     Variance
# 0  SN001 - Number 1   90  437  181.889328  56.986889  3247.505538
# 1  SN001 - Number 2   79  437  184.713710  55.501841  3080.454328
# 2  SN001 - Number 3   54  430  185.809717  52.365426  2742.137881
# 3  SN001 - Number 4  109  370  182.202381  51.292991  2630.970947
# 4  SN001 - Number 5  103  419  190.701245  55.399885  3069.147260

# %%
df1.corr()
# Out:
# C:\Users\Mreza\AppData\Local\Temp\ipykernel_20184\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                Min       Max      Mean       Std  Variance
# Min       1.000000  0.176259  0.806410 -0.035940 -0.007700
# Max       0.176259  1.000000  0.597127  0.909717  0.701083
# Mean      0.806410  0.597127  1.000000  0.473269  0.420861
# Std      -0.035940  0.909717  0.473269  1.000000  0.880069
# Variance -0.007700  0.701083  0.420861  0.880069  1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
plt.savefig('Output/Correlation_Heatmap.png',dpi=240)
plt.show()
# Out:
# C:\Users\Mreza\AppData\Local\Temp\ipykernel_20184\3070305341.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True)

# %%
## Splitted with loss
df2 = pd.read_csv('Output/Splitted_Csv.csv')

# %%
df2.head()
# Out:
#                Name  Min  Max        Mean        Std     Variance         Loss
# 0  SN001 - Number 1   90  437  181.889328  56.986889  3247.505538  3847.972332
# 1  SN001 - Number 2   79  437  184.713710  55.501841  3080.454328  3616.157258
# 2  SN001 - Number 3   54  430  185.809717  52.365426  2742.137881  3114.356275
# 3  SN001 - Number 4  109  370  182.202381  51.292991  2630.970947  3122.926587
# 4  SN001 - Number 5  103  419  190.701245  55.399885  3069.147260  3452.190871

# %%
sns.heatmap(df2.corr(),annot=True)
plt.savefig('Output/Correlation_Heatmap_Loss.png',dpi=240)
plt.show()
# Out:
# C:\Users\Mreza\AppData\Local\Temp\ipykernel_20184\3061177413.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(),annot=True)

# %% [markdown]
# ## Processing

# %%
## Load section
df = pd.read_csv('Output/Org/Splitted_HRV_pts.csv')

# %%
len(df)
# Out:
# 14685

# %%
arrs = []
for item in set(df['Name']):
    arrs.append(item)
print(len(arrs))
arrs = sorted(list(arrs))
print(arrs)
# Out:
# 151
# ['SN001', 'SN002', 'SN003', 'SN004', 'SN005', 'SN006', 'SN007', 'SN008', 'SN009', 'SN010', 'SN011', 'SN012', 'SN013', 'SN015', 'SN016', 'SN017', 'SN018', 'SN019', 'SN020', 'SN021', 'SN022', 'SN023', 'SN024', 'SN025', 'SN026', 'SN027', 'SN028', 'SN029', 'SN030', 'SN031', 'SN032', 'SN033', 'SN034', 'SN035', 'SN036', 'SN037', 'SN038', 'SN039', 'SN040', 'SN041', 'SN042', 'SN043', 'SN044', 'SN045', 'SN046', 'SN047', 'SN048', 'SN049', 'SN050', 'SN051', 'SN052', 'SN053', 'SN054', 'SN055', 'SN056', 'SN057', 'SN058', 'SN059', 'SN060', 'SN061', 'SN062', 'SN063', 'SN065', 'SN066', 'SN067', 'SN068', 'SN069', 'SN070', 'SN071', 'SN072', 'SN073', 'SN074', 'SN075', 'SN076', 'SN077', 'SN078', 'SN079', 'SN080', 'SN081', 'SN082', 'SN083', 'SN084', 'SN085', 'SN086', 'SN087', 'SN088', 'SN089', 'SN090', 'SN091', 'SN092', 'SN093', 'SN094', 'SN095', 'SN096', 'SN097', 'SN098', 'SN099', 'SN100', 'SN101', 'SN102', 'SN103', 'SN104', 'SN105', 'SN106', 'SN107', 'SN108', 'SN109', 'SN110', 'SN111', 'SN112', 'SN113', 'SN114', 'SN115', 'SN116', 'SN117', 'SN118', 'SN119', 'SN120', 'SN121', 'SN122', 'SN123', 'SN124', 'SN125', 'SN126', 'SN127', 'SN128', 'SN129', 'SN130', 'SN131', 'SN132', 'SN133', 'SN134', 'SN136', 'SN137', 'SN138', 'SN139', 'SN140', 'SN141', 'SN142', 'SN143', 'SN144', 'SN145', 'SN146', 'SN147', 'SN148', 'SN149', 'SN150', 'SN151', 'SN152', 'SN153', 'SN154']

# %%
arr_n = []
for item in arrs:
    arr_n.append(len(df.loc[df['Name'] == item]))
print(arr_n)
# Out:
# [109, 99, 109, 123, 80, 77, 110, 94, 96, 86, 127, 118, 118, 94, 133, 116, 110, 102, 126, 112, 108, 106, 103, 89, 118, 102, 106, 89, 115, 53, 40, 41, 103, 92, 27, 111, 130, 82, 48, 98, 130, 134, 109, 86, 81, 102, 131, 99, 100, 113, 67, 110, 62, 112, 113, 78, 104, 86, 109, 106, 65, 106, 84, 108, 107, 80, 85, 77, 145, 95, 93, 110, 127, 77, 82, 76, 121, 107, 113, 101, 125, 112, 95, 56, 101, 120, 69, 120, 76, 116, 87, 122, 109, 100, 97, 5, 95, 100, 102, 88, 129, 90, 105, 77, 71, 112, 101, 105, 50, 91, 88, 65, 103, 90, 80, 82, 121, 124, 128, 98, 84, 101, 159, 71, 123, 80, 87, 52, 124, 119, 74, 99, 60, 78, 128, 92, 145, 118, 105, 96, 93, 79, 107, 86, 106, 73, 82, 101, 123, 105, 39]

# %%
arr_z = []
for i in range(len(arr_n)):
    if i == 0:
        arr_z.append(arr_n[i])
    else:
        arr_z.append(arr_n[i]+arr_z[i-1])
print(arr_z)
print(len(arr_z))
# Out:
# [109, 208, 317, 440, 520, 597, 707, 801, 897, 983, 1110, 1228, 1346, 1440, 1573, 1689, 1799, 1901, 2027, 2139, 2247, 2353, 2456, 2545, 2663, 2765, 2871, 2960, 3075, 3128, 3168, 3209, 3312, 3404, 3431, 3542, 3672, 3754, 3802, 3900, 4030, 4164, 4273, 4359, 4440, 4542, 4673, 4772, 4872, 4985, 5052, 5162, 5224, 5336, 5449, 5527, 5631, 5717, 5826, 5932, 5997, 6103, 6187, 6295, 6402, 6482, 6567, 6644, 6789, 6884, 6977, 7087, 7214, 7291, 7373, 7449, 7570, 7677, 7790, 7891, 8016, 8128, 8223, 8279, 8380, 8500, 8569, 8689, 8765, 8881, 8968, 9090, 9199, 9299, 9396, 9401, 9496, 9596, 9698, 9786, 9915, 10005, 10110, 10187, 10258, 10370, 10471, 10576, 10626, 10717, 10805, 10870, 10973, 11063, 11143, 11225, 11346, 11470, 11598, 11696, 11780, 11881, 12040, 12111, 12234, 12314, 12401, 12453, 12577, 12696, 12770, 12869, 12929, 13007, 13135, 13227, 13372, 13490, 13595, 13691, 13784, 13863, 13970, 14056, 14162, 14235, 14317, 14418, 14541, 14646, 14685]
# 151

# %%
arr_cu = []
for i in range(len(arrs)):
    if i == 0:
        arr_cu.append([0,arr_z[i],arrs[i]])
    else:
        arr_cu.append([arr_z[i-1],arr_z[i],arrs[i]])
print(arr_cu)
# Out:
# [[0, 109, 'SN001'], [109, 208, 'SN002'], [208, 317, 'SN003'], [317, 440, 'SN004'], [440, 520, 'SN005'], [520, 597, 'SN006'], [597, 707, 'SN007'], [707, 801, 'SN008'], [801, 897, 'SN009'], [897, 983, 'SN010'], [983, 1110, 'SN011'], [1110, 1228, 'SN012'], [1228, 1346, 'SN013'], [1346, 1440, 'SN015'], [1440, 1573, 'SN016'], [1573, 1689, 'SN017'], [1689, 1799, 'SN018'], [1799, 1901, 'SN019'], [1901, 2027, 'SN020'], [2027, 2139, 'SN021'], [2139, 2247, 'SN022'], [2247, 2353, 'SN023'], [2353, 2456, 'SN024'], [2456, 2545, 'SN025'], [2545, 2663, 'SN026'], [2663, 2765, 'SN027'], [2765, 2871, 'SN028'], [2871, 2960, 'SN029'], [2960, 3075, 'SN030'], [3075, 3128, 'SN031'], [3128, 3168, 'SN032'], [3168, 3209, 'SN033'], [3209, 3312, 'SN034'], [3312, 3404, 'SN035'], [3404, 3431, 'SN036'], [3431, 3542, 'SN037'], [3542, 3672, 'SN038'], [3672, 3754, 'SN039'], [3754, 3802, 'SN040'], [3802, 3900, 'SN041'], [3900, 4030, 'SN042'], [4030, 4164, 'SN043'], [4164, 4273, 'SN044'], [4273, 4359, 'SN045'], [4359, 4440, 'SN046'], [4440, 4542, 'SN047'], [4542, 4673, 'SN048'], [4673, 4772, 'SN049'], [4772, 4872, 'SN050'], [4872, 4985, 'SN051'], [4985, 5052, 'SN052'], [5052, 5162, 'SN053'], [5162, 5224, 'SN054'], [5224, 5336, 'SN055'], [5336, 5449, 'SN056'], [5449, 5527, 'SN057'], [5527, 5631, 'SN058'], [5631, 5717, 'SN059'], [5717, 5826, 'SN060'], [5826, 5932, 'SN061'], [5932, 5997, 'SN062'], [5997, 6103, 'SN063'], [6103, 6187, 'SN065'], [6187, 6295, 'SN066'], [6295, 6402, 'SN067'], [6402, 6482, 'SN068'], [6482, 6567, 'SN069'], [6567, 6644, 'SN070'], [6644, 6789, 'SN071'], [6789, 6884, 'SN072'], [6884, 6977, 'SN073'], [6977, 7087, 'SN074'], [7087, 7214, 'SN075'], [7214, 7291, 'SN076'], [7291, 7373, 'SN077'], [7373, 7449, 'SN078'], [7449, 7570, 'SN079'], [7570, 7677, 'SN080'], [7677, 7790, 'SN081'], [7790, 7891, 'SN082'], [7891, 8016, 'SN083'], [8016, 8128, 'SN084'], [8128, 8223, 'SN085'], [8223, 8279, 'SN086'], [8279, 8380, 'SN087'], [8380, 8500, 'SN088'], [8500, 8569, 'SN089'], [8569, 8689, 'SN090'], [8689, 8765, 'SN091'], [8765, 8881, 'SN092'], [8881, 8968, 'SN093'], [8968, 9090, 'SN094'], [9090, 9199, 'SN095'], [9199, 9299, 'SN096'], [9299, 9396, 'SN097'], [9396, 9401, 'SN098'], [9401, 9496, 'SN099'], [9496, 9596, 'SN100'], [9596, 9698, 'SN101'], [9698, 9786, 'SN102'], [9786, 9915, 'SN103'], [9915, 10005, 'SN104'], [10005, 10110, 'SN105'], [10110, 10187, 'SN106'], [10187, 10258, 'SN107'], [10258, 10370, 'SN108'], [10370, 10471, 'SN109'], [10471, 10576, 'SN110'], [10576, 10626, 'SN111'], [10626, 10717, 'SN112'], [10717, 10805, 'SN113'], [10805, 10870, 'SN114'], [10870, 10973, 'SN115'], [10973, 11063, 'SN116'], [11063, 11143, 'SN117'], [11143, 11225, 'SN118'], [11225, 11346, 'SN119'], [11346, 11470, 'SN120'], [11470, 11598, 'SN121'], [11598, 11696, 'SN122'], [11696, 11780, 'SN123'], [11780, 11881, 'SN124'], [11881, 12040, 'SN125'], [12040, 12111, 'SN126'], [12111, 12234, 'SN127'], [12234, 12314, 'SN128'], [12314, 12401, 'SN129'], [12401, 12453, 'SN130'], [12453, 12577, 'SN131'], [12577, 12696, 'SN132'], [12696, 12770, 'SN133'], [12770, 12869, 'SN134'], [12869, 12929, 'SN136'], [12929, 13007, 'SN137'], [13007, 13135, 'SN138'], [13135, 13227, 'SN139'], [13227, 13372, 'SN140'], [13372, 13490, 'SN141'], [13490, 13595, 'SN142'], [13595, 13691, 'SN143'], [13691, 13784, 'SN144'], [13784, 13863, 'SN145'], [13863, 13970, 'SN146'], [13970, 14056, 'SN147'], [14056, 14162, 'SN148'], [14162, 14235, 'SN149'], [14235, 14317, 'SN150'], [14317, 14418, 'SN151'], [14418, 14541, 'SN152'], [14541, 14646, 'SN153'], [14646, 14685, 'SN154']]

# %%
def Caller():
    for item in arr_cu:
        if i>=item[0] and i<item[1]:
            mi = i - item[1]
            lght = item[1] - item[0]
            ind = lght + mi
    return ind

# %%
def loss(arr):
    tmp=0
    for i in range(len(arr)-1):
        tmp += (arr[i+1] - arr[i])**2
    m = len(arr)
    loss = 1/(2*m) * (tmp)
    return loss

# %%
for i in range(len(df)):
    # for j in len(df.loc[df['Name'] == arrs[zx]]):

    text = df['Points'][i]
    text = ast.literal_eval(text)

    n1 = [text[z]/256 for z in range(0,len(text)-1)] #x
    n2 = [text[z]/256 for z in range(1,len(text))]   #y
    plt.scatter(n1,n2)
    fname = df['Name'][i]
    plt.title(f'{fname} - Number {Caller()+1}')
    plt.xlabel(df['Stage'][i])
    plt.savefig(f'Output/Scatter/{fname} - Number {Caller()+1}.png',dpi=100)
    plt.close()
    with open('Output/loss_splitted.csv','a') as file:
        file.write(f'{loss(text)}\n')
    # plt.show()

# %%
#Continue 8379:
for i in range(8379,len(df)):
    # for j in len(df.loc[df['Name'] == arrs[zx]]):

    text = df['Points'][i]
    text = ast.literal_eval(text)

    n1 = [text[z]/256 for z in range(0,len(text)-1)] #x
    n2 = [text[z]/256 for z in range(1,len(text))]   #y
    plt.scatter(n1,n2)
    fname = df['Name'][i]
    plt.title(f'{fname} - Number {Caller()+1}')
    plt.xlabel(df['Stage'][i])
    plt.savefig(f'Output/Scatter/{fname} - Number {Caller()+1}.png',dpi=100)
    plt.close()
    with open('Output/loss_splitted.csv','a') as file:
        file.write(f'{loss(text)}\n')
    # plt.show()

# %% [markdown]
# ### Sample 1 - Good

# %%
print(arr_cu[30])
# Out:
# [3128, 3168, 'SN032']

# %%
a_point = arr_cu[30][0]+7
a_point
# Out:
# 3135

# %%
text = df['Points'][4626]
text = ast.literal_eval(text)
n1 = [text[z]/256 for z in range(0,len(text)-1)] #x
n2 = [text[z]/256 for z in range(1,len(text))]   #y

# %%
# sns.kdeplot(data=poincare)
plt.figure(figsize=(3,6))
sns.boxplot(poincare)
plt.savefig('Box-sample.png',dpi=200)

# %%
sns.violinplot(poincare)
plt.savefig('violin-sample.png',dpi=200)

# %%
# plt.axes([0, 0, 1.3, 1])
plt.figure(figsize=(16,8))
plt.plot(n1,n2,'o--', markerfacecolor='red')
plt.plot(n1[0],n2[0],'D', label="Start Point")
plt.plot(n1[-1],n2[-1],'D', label="End Point", markerfacecolor='green')
plt.legend()
plt.title("Points Path")
plt.xlabel("SN032-N08")
# plt.xticks(np.arange(0.4,1.4,step=0.05))
plt.savefig("Pts-path.png",dpi=300)
plt.show()

# %%
ax=plt.axes()
fig=plt.figure()
ax.scatter(n1,n2,label='Poicare')
sns.kdeplot(poincare,ax=ax,color='red',label='Density')
ax.legend()
ax.figure.savefig("Together-sample.png",dpi=200)

# %%
plt.scatter(n1,n2)
plt.savefig("poicare-sample.png",dpi=200)

# %%
plt.plot(text)
plt.savefig("HRV-sample.png",dpi=200)

# %%
poincare = n1 and n2
len(poincare)
# Out:
# 172

# %%
plt.plot(poincare)

# %%
sns.distplot(poincare)
plt.savefig("Dist-sample.png",dpi=200)
# sns.kdeplot(poincare)
# Out:
# C:\Users\Mreza\AppData\Local\Temp\ipykernel_12300\3733329081.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(poincare)

# %% [markdown]
# ### Sample 2 - Bad

# %%
print(arr_cu[20])
# Out:
# [2139, 2247, 'SN022']

# %%
a_point = arr_cu[20][0]+6
a_point
# Out:
# 2145

# %%
text = df['Points'][a_point]
text = ast.literal_eval(text)
n1 = [text[z]/256 for z in range(0,len(text)-1)] #x
n2 = [text[z]/256 for z in range(1,len(text))]   #y

# %%
poincare = n1 and n2
len(poincare)
# Out:
# 253

# %%
# plt.plot(text)
fig, ax = plt.subplots(3,2, figsize=(18,12))
# ax.figure(figsize=(18,12))
ax[0,0].plot(text)
ax[0,0].set_title('HRV - Signal')
#---
ax[1,0].scatter(n1,n2)
ax[1,0].set_title("Poincare")
#---
sns.distplot(poincare,ax=ax[2,0])
ax[2,0].set_title("Distribution")
#---
ax[0,1].scatter(n1,n2,label='Poicare')
sns.kdeplot(poincare,ax=ax[0,1],color='red',label='Density')
ax[0,1].legend()
ax[0,1].set_title("Poincare + Density")
#---
sns.violinplot(poincare,ax=ax[1,1],width=0.4)
sns.boxplot(poincare,ax=ax[1,1], width=0.08,boxprops={'zorder': 2}, palette='rocket') #zorder for being upper layer
ax[1,1].set_title("Violin + Box Plot")
#---
ax[2,1].plot(n1,n2,'o--', markerfacecolor='red')
ax[2,1].plot(n1[0],n2[0],'D', label="Start Point")
ax[2,1].plot(n1[-1],n2[-1],'D', label="End Point", markerfacecolor='green')
ax[2,1].legend()
ax[2,1].set_title("Points Path")

fig.suptitle('Sample 4626')

fig.savefig("Sample 4626.png",dpi=400)
fig.show()
# Out:
# C:\Users\Mreza\AppData\Local\Temp\ipykernel_11972\4098734744.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(poincare,ax=ax[2,0])
# C:\Users\Mreza\AppData\Local\Temp\ipykernel_11972\4098734744.py:31: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
